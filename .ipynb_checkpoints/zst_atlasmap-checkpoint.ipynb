# %% [markdown]
# ### Atlas mapping
# This code will take various raw data and map them to a specified atlas. This can be done either by
# 1. labelling xyz coordinates with atlas keys
# 2. by extracting region averages using the atlas VOIs as masks on a full resolution image file.

# %%
import ants
import zst_atlasmap_functions as am
import os
import pandas as pd
import csv
import matplotlib.pyplot as plt
import scipy.io 
from imp import reload
import numpy as np

# %% [markdown]
# ### Housekeeping

# %%
# Housekeeping
#=========================================================================
reload(am)
atlas = '/Users/roschkoenig/Dropbox/Research/0002 Tools/Standalone/zbb2/anatomy/pajevic1.tif'
base  = '/Volumes/GoogleDrive/My Drive/Research/2003 Zebrafish Structure'
F     = am.housekeeping(base, 'Ashourvan')

# %%
# Load atlas data
#=========================================================================
F['atlas']
atlas = scipy.io.loadmat(F['atlas']+os.sep+'kmeans_MATLAB_iter_200_DS_K_1000_Interp3.mat')['Vq']

# %%
# Map xyz location to atlas
#=========================================================================
struct     = F['data'] +os.sep+ 'Kunst_Connections.csv'
data       = pd.read_csv(struct)
conversion = (1,1,2.5)
emp_mat    = np.zeros((atlas.max(), atlas.max()))
connect    = emp_mat
connect_sc = emp_mat

oldstart = 0
starts   = []
stops    = []
labl     = []

# Extract atlas labels for each neurite 
#-------------------------------------------------------------------------
for row in range(2000): #data.index: 
    if np.mod(row,1000) == 0: print(row); print(connect_sc.max())
    start = (data['start_x'][row], data['start_y'][row], data['start_z'][row])
    stop  = (data['stop_x'][row], data['stop_y'][row], data['stop_z'][row])
    st_sc = np.divide(stop,conversion).round().astype('int') 
    
    if stop[2] < 138 * conversion[2]:    # exclude end points outside the atlas range 
        if start == oldstart:
            labl.append(atlas[st_sc[0], st_sc[1], st_sc[2]])
        else:
            oldstart = start
            temp_mat = emp_mat
            if labl is not None:
                for l in labl:
                    for ll in labl:
                        temp_mat[l,ll] = temp_mat[l,ll] + 1
                connect    = connect + temp_mat
                connect_sc = connect_sc + temp_mat / temp_mat.sum()
            
                    
        starts.append(start)
        stops.append(stop)

# Load xyz coordinates
#-------------------------------------------------------------------------
# Out:
# 0
# 0.0
# /Users/roschkoenig/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# 1000
# nan

# %%
conversion = (1,1,2.5) 
f,a = plt.subplots(2, figsize=(10,10))

coord = np.ndarray(0)
col = np.ndarray(0)

for s in range(len(starts)):
    c_sc  = np.divide(starts[s],conversion).round().astype('int') 
    if c_sc[2] < 138:
        tcol  = atlas[c_sc[0], c_sc[1], c_sc[2]]
        coord = c_sc if len(coord) == 0 else np.vstack((coord, c_sc))
        col   = np.asarray(tcol) if np.size(col) == 0 else np.vstack((col, tcol))

a[0].scatter(coord[:,1], coord[:,0], s=2, c=col[:,0], cmap='Set1')
a[1].scatter(coord[:,1], coord[:,2], s=2, c=col[:,0], cmap='Set1')

# %%
connect_sc.max()
# Out:
# /Users/roschkoenig/.local/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# nan

# %%
# Extract averages from atlas VOIs 
#-------------------------------------------------------------------------
cell_coordinates = pd.unique(starts)

# %%
cell_coordinates.shape
# Out:
# (3114,)

# %%
# Load atlas file
#=========================================================================
atlas = ants.image_read(F['atlas'])
atlas.set_spacing([.3, .3, 1.])

# %%
td = data[data['ID']=='R002']
for row in td.index:
    plt.plot([td['start_x'][row],td['stop_x'][row]],[td['start_y'][row],td['stop_y'][row]])
# Out:
# /Users/roschkoenig/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
np.shape(atdat['Vq'])
# Out:
# (621, 1406, 138)

# %%
plt.imshow(atdat[:,:,100])
